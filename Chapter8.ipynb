# %% [markdown]
# Chapter 8

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# First Dict with two 2 and 4 columns
#data_one = {'A' : ['A1','A2','A3','A4'] , 'B' : ['B1','B2','B3','B4']}
data_one = {'A' : ['A0','A1','A2','A3'] , 'B' : ['B0','B1','B2','B3'] , 'C' : ['C0','C1','C2','C3'] , 'D' : ['D0','D1','D2', 'D3']}
data_two = {'A' : ['A4','A5','A6','A7'] , 'B' : ['B4','B5','B6','B7'] , 'C' : ['C4','C5','C6','C7'] , 'D' : ['D4','D5','D5', 'D7']}
# Converting to DataFrames
df_one=pd.DataFrame(data_one)
df_two=pd.DataFrame(data_two)
print(df_one)
print(df_two)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D5
# 3  A7  B7  C7  D7

# %%
pd.concat([df_one,df_two],axis=1,ignore_index=True)
# Out:
#     0   1   2   3   4   5   6   7
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D5
# 3  A3  B3  C3  D3  A7  B7  C7  D7
