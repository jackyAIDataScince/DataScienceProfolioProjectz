# %% [markdown]
# Chapter 5

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
def multiply(x):
  return x *1.1

# %%
df['total_bill_multiply'] = df['total_bill'].apply(multiply)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_multiply
# 0         16.99  1.01  Female     No   Sun  Dinner     2               18.689
# 1         10.34  1.66    Male     No   Sun  Dinner     3               11.374
# 2         21.01  3.50    Male     No   Sun  Dinner     3               23.111
# 3         23.68  3.31    Male     No   Sun  Dinner     2               26.048
# 4         24.59  3.61  Female     No   Sun  Dinner     4               27.049
# ..          ...   ...     ...    ...   ...     ...   ...                  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               31.933
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2               29.898
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2               24.937
# 242       17.82  1.75    Male     No   Sat  Dinner     2               19.602
# 243       18.78  3.00  Female     No  Thur  Dinner     2               20.658
#
# [244 rows x 8 columns]

# %% [markdown]
# # Lamba #

# %%
df['total_bill_labda'] = df['total_bill'].apply(lambda x: x *1.1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_multiply  \
# 0        18.689  1.01  Female     No   Sun  Dinner     2               18.689
# 1        11.374  1.66    Male     No   Sun  Dinner     3               11.374
# 2        23.111  3.50    Male     No   Sun  Dinner     3               23.111
# 3        26.048  3.31    Male     No   Sun  Dinner     2               26.048
# 4        27.049  3.61  Female     No   Sun  Dinner     4               27.049
# ..          ...   ...     ...    ...   ...     ...   ...                  ...
# 239      31.933  5.92    Male     No   Sat  Dinner     3               31.933
# 240      29.898  2.00  Female    Yes   Sat  Dinner     2               29.898
# 241      24.937  2.00    Male    Yes   Sat  Dinner     2               24.937
# 242      19.602  1.75    Male     No   Sat  Dinner     2               19.602
# 243      20.658  3.00  Female     No  Thur  Dinner     2               20.658
#
#      total_bill_labda
# ...

# %%
df['total_bill_tips'] = df.apply(lambda row:row['total_bill'] + row['tip'], axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_multiply  \
# 0        18.689  1.01  Female     No   Sun  Dinner     2               18.689
# 1        11.374  1.66    Male     No   Sun  Dinner     3               11.374
# 2        23.111  3.50    Male     No   Sun  Dinner     3               23.111
# 3        26.048  3.31    Male     No   Sun  Dinner     2               26.048
# 4        27.049  3.61  Female     No   Sun  Dinner     4               27.049
# ..          ...   ...     ...    ...   ...     ...   ...                  ...
# 239      31.933  5.92    Male     No   Sat  Dinner     3               31.933
# 240      29.898  2.00  Female    Yes   Sat  Dinner     2               29.898
# 241      24.937  2.00    Male    Yes   Sat  Dinner     2               24.937
# 242      19.602  1.75    Male     No   Sat  Dinner     2               19.602
# 243      20.658  3.00  Female     No  Thur  Dinner     2               20.658
#
# ...

# %%
df['unit_price'] = df.apply(lambda row:row['total_bill'] / row['size'], axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_multiply  \
# 0        18.689  1.01  Female     No   Sun  Dinner     2               18.689
# 1        11.374  1.66    Male     No   Sun  Dinner     3               11.374
# 2        23.111  3.50    Male     No   Sun  Dinner     3               23.111
# 3        26.048  3.31    Male     No   Sun  Dinner     2               26.048
# 4        27.049  3.61  Female     No   Sun  Dinner     4               27.049
# ..          ...   ...     ...    ...   ...     ...   ...                  ...
# 239      31.933  5.92    Male     No   Sat  Dinner     3               31.933
# 240      29.898  2.00  Female    Yes   Sat  Dinner     2               29.898
# 241      24.937  2.00    Male    Yes   Sat  Dinner     2               24.937
# 242      19.602  1.75    Male     No   Sat  Dinner     2               19.602
# 243      20.658  3.00  Female     No  Thur  Dinner     2               20.658
#
# ...

# %%
df2 = sns.load_dataset('tips')

# %%
df2['over_20'] = df2['total_bill'].apply(lambda x:'True' if x >= 20 else 'False')

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size over_20
# 0         16.99  1.01  Female     No   Sun  Dinner     2   False
# 1         10.34  1.66    Male     No   Sun  Dinner     3   False
# 2         21.01  3.50    Male     No   Sun  Dinner     3    True
# 3         23.68  3.31    Male     No   Sun  Dinner     2    True
# 4         24.59  3.61  Female     No   Sun  Dinner     4    True
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    True
# 242       17.82  1.75    Male     No   Sat  Dinner     2   False
# 243       18.78  3.00  Female     No  Thur  Dinner     2   False
#
# [244 rows x 8 columns]
