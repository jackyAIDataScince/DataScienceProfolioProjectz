# %% [markdown]
# Chapter 9 to_csvでファイル保存

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df = df[df['size'] == 6]

# %%
df
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 125       29.80  4.2  Female     No  Thur   Lunch     6
# 141       34.30  6.7    Male     No  Thur   Lunch     6
# 143       27.05  5.0  Female     No  Thur   Lunch     6
# 156       48.17  5.0    Male     No   Sun  Dinner     6

# %%
import pandas as pd2

df2.to_csv('tips.pipe', sep='shift-jis',index=False)

# %%
#df2 = pd2.read_csv('tips.csv')
df2
# Out:
#    Unnamed: 0.1  Unnamed: 0  total_bill   tip     sex smoker  day    time  \
# 0             0           0       16.99  1.01  Female     No  Sun  Dinner
# 1             1           1       10.34  1.66    Male     No  Sun  Dinner
# 2             2           2       21.01  3.50    Male     No  Sun  Dinner
# 3             3           3       23.68  3.31    Male     No  Sun  Dinner
# 4             4           4       24.59  3.61  Female     No  Sun  Dinner
# 5             5           5       25.29  4.71    Male     No  Sun  Dinner
# 6             6           6        8.77  2.00    Male     No  Sun  Dinner
# 7             7           7       26.88  3.12    Male     No  Sun  Dinner
# 8             8           8       15.04  1.96    Male     No  Sun  Dinner
#
#    size
# 0     2
# 1     3
# 2     3
# 3     2
# 4     4
# 5     4
# 6     2
# 7     4
# 8     2

# %%
import datetime
import pandas as pd

df = pd.DataFrame({'date':[datetime.datetime(2022, 1,1,0,0),
                           datetime.datetime(2022, 1,2,0,0)],
                   'value':[100,200]})

df

df
# Out:
#         date  value
# 0 2022-01-01    100
# 1 2022-01-02    200

# %%
df.to_csv('DateFormat.csv', date_format='%Y/%m/%d %H:%M:%S', index=False)
pd.read_csv('DateFormat.csv')
# Out:
#                   date  value
# 0  2022/01/01 00:00:00    100
# 1  2022/01/02 00:00:00    200
