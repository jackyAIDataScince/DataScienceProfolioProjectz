# %%
import pandas as pds
import seaborn as sns


'''Ignore warnings'''
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_size = df.groupby('size')

# %%
df_size.mean(numeric_only=True)
# Out:
#       total_bill       tip
# size
# 1       7.242500  1.437500
# 2      16.448013  2.582308
# 3      23.277632  3.393158
# 4      28.613514  4.135405
# 5      30.068000  4.028000
# 6      34.830000  5.225000

# %%
df.groupby(['day','sex'])['total_bill'].mean(numeric_only=True)
# Out:
# day   sex
# Thur  Male      18.714667
#       Female    16.715312
# Fri   Male      19.857000
#       Female    14.145556
# Sat   Male      20.802542
#       Female    19.680357
# Sun   Male      21.887241
#       Female    19.872222
# Name: total_bill, dtype: float64

# %%
df.groupby(['sex','sex'])['total_bill'].mean(numeric_only=True)
df.dropna()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby('sex').agg({'total_bill':'sum','tip':'mean'})
# Out:
#         total_bill       tip
# sex
# Male       3256.82  3.089618
# Female     1570.95  2.833448

# %%
df.groupby('sex').agg({'total_bill':['sum','mean','max']})
# Out:
#        total_bill
#               sum       mean    max
# sex
# Male      3256.82  20.744076  50.81
# Female    1570.95  18.056897  44.30

# %%
df.groupby('time').size()
# Out:
# time
# Lunch      68
# Dinner    176
# dtype: int64

# %%
df.groupby('sex').get_group('Female').head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# 18       16.97  3.50  Female     No  Sun  Dinner     3
# 21       20.29  2.75  Female     No  Sat  Dinner     2
# 22       15.77  2.23  Female     No  Sat  Dinner     2
# 29       19.65  3.00  Female     No  Sat  Dinner     2
# 32       15.06  3.00  Female     No  Sat  Dinner     2
# 33       20.69  2.45  Female     No  Sat  Dinner     4
# 37       16.93  3.07  Female     No  Sat  Dinner     3
# 51       10.29  2.60  Female     No  Sun  Dinner     2
# 52       34.81  5.20  Female     No  Sun  Dinner     4
# 57       26.41  1.50  Female     No  Sat  Dinner     2
# 66       16.45  2.47  Female     No  Sat  Dinner     2
# ...
